# %%
# !git
# Out:
# usage: git [--version] [--help] [-C <path>] [-c <name>=<value>]
#            [--exec-path[=<path>]] [--html-path] [--man-path] [--info-path]
#            [-p | --paginate | -P | --no-pager] [--no-replace-objects] [--bare]
#            [--git-dir=<path>] [--work-tree=<path>] [--namespace=<name>]
#            [--super-prefix=<path>] [--config-env=<name>=<envvar>]
#            <command> [<args>]
#
# These are common Git commands used in various situations:
#
# start a working area (see also: git help tutorial)
#    clone     Clone a repository into a new directory
#    init      Create an empty Git repository or reinitialize an existing one
#
# work on the current change (see also: git help everyday)
#    add       Add file contents to the index
#    mv        Move or rename a file, a directory, or a symlink
#    restore   Restore working tree files
#    rm        Remove files from the working tree and from the index
#
# examine the history and state (see also: git help revisions)
#    bisect    Use binary search to find the commit that introduced a bug
#    diff      Show changes between commits, commit and working tree, etc
#    grep      Print lines matching a pattern
#    log       Show commit logs
#    show      Show various types of objects
#    status    Show the working tree status
#
# grow, mark and tweak your common history
#    branch    List, create, or delete branches
#    commit    Record changes to the repository
#    merge     Join two or more development histories together
#    rebase    Reapply commits on top of another base tip
#    reset     Reset current HEAD to the specified state
#    switch    Switch branches
#    tag       Create, list, delete or verify a tag object signed with GPG
#
# collaborate (see also: git help workflows)
#    fetch     Download objects and refs from another repository
#    pull      Fetch from and integrate with another repository or a local branch
#    push      Update remote refs along with associated objects
#
# 'git help -a' and 'git help -g' list available subcommands and some
# concept guides. See 'git help <command>' or 'git help <concept>'
# to read about a specific subcommand or concept.
# See 'git help git' for an overview of the system.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/ais
# Out:
# /content/drive/MyDrive/ais

# %%
# !pip install ClearML
# Out:
# Collecting ClearML
#   Downloading clearml-1.18.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.11/dist-packages (from ClearML) (25.3.0)
# Collecting furl>=2.0.0 (from ClearML)
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from ClearML) (4.23.0)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.11/dist-packages (from ClearML) (2.0.2)
# Collecting pathlib2>=2.3.0 (from ClearML)
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: Pillow>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from ClearML) (11.2.1)
# Requirement already satisfied: psutil>=3.4.2 in /usr/local/lib/python3.11/dist-packages (from ClearML) (5.9.5)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from ClearML) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from ClearML) (2.9.0.post0)
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.11/dist-packages (from ClearML) (6.0.2)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.11/dist-packages (from ClearML) (2.32.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ClearML) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from ClearML) (2.4.0)
# Collecting pyjwt<2.10.0,>=2.4.0 (from ClearML)
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.11/dist-packages (from ClearML) (0.36.2)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->ClearML)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6.0->ClearML) (2025.4.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6.0->ClearML) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing<0.40->ClearML) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->ClearML) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->ClearML) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20.0->ClearML) (2025.4.26)
# Downloading clearml-1.18.0-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.8 MB/s eta 0:00:00
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pyjwt, pathlib2, orderedmultidict, furl, ClearML
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.10.1
#     Uninstalling PyJWT-2.10.1:
#       Successfully uninstalled PyJWT-2.10.1
# Successfully installed ClearML-1.18.0 furl-2.1.4 orderedmultidict-1.0.1 pathlib2-2.3.7.post1 pyjwt-2.9.0

# %% [markdown]
# 一个pipeline,一个agent.

# %%
# !clearml-init
# Out:
# ClearML SDK setup process
#
# Please create new clearml credentials through the settings page in your `clearml-server` web app (e.g. http://localhost:8080//settings/workspace-configuration)
# Or create a free account at https://app.clear.ml/settings/workspace-configuration
#
# In settings page, press "Create new credentials", then press "Copy to clipboard".
#
# Paste copied configuration here:
# api {   # Guankai Qiao's workspace   web_server: https://app.clear.ml/   api_server: https://api.clear.ml   files_server: https://files.clear.ml   credentials {     "access_key" = "9JEK7C1DPK3IRAWTKGYM6S6IKZQU62"     "secret_key" = "Nqzqv5hHzwMrrL6F4E8IxGikFT006a2Sl8-iyRTXAcoxTH3hDW43O2ZtORTiAMLZcrs"   } }
# Detected credentials key="9JEK7C1DPK3IRAWTKGYM6S6IKZQU62" secret="Nqzq***"
#
# ClearML Hosts configuration:
# Web App: https://app.clear.ml/
# API: https://api.clear.ml
# File Store: https://files.clear.ml
#
# Verifying credentials ...
# Credentials verified!
#
# New configuration stored in /root/clearml.conf
# ClearML setup completed successfully.

# %%
api {
  # Guankai Qiao's workspace
  web_server: https://app.clear.ml/
  api_server: https://api.clear.ml
  files_server: https://files.clear.ml
  credentials {
    "access_key" = "9JEK7C1DPK3IRAWTKGYM6S6IKZQU62"
    "secret_key" = "Nqzqv5hHzwMrrL6F4E8IxGikFT006a2Sl8-iyRTXAcoxTH3hDW43O2ZtORTiAMLZcrs"
  }
}

# %% [markdown]
# api {
#   # Guankai Qiao's workspace
#   web_server: https://app.clear.ml/
#   api_server: https://api.clear.ml
#   files_server: https://files.clear.ml
#   credentials {
#     "access_key" = "9JEK7C1DPK3IRAWTKGYM6S6IKZQU62"
#     "secret_key" = "Nqzqv5hHzwMrrL6F4E8IxGikFT006a2Sl8-iyRTXAcoxTH3hDW43O2ZtORTiAMLZcrs"
#   }
# }

# %%
# !python step1_upload_dataset.py
# Out:
# ClearML Task: created new task id=687ba1c6b7b44cb0b3b4761bcd8ebb92
# 2025-05-04 11:25:27,384 - clearml.Task - INFO - No repository found, storing script code instead
# 2025-05-04 11:25:28.417320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746357928.437489   16578 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746357928.443734   16578 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 11:25:28.464101: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/727a6a00559349e08d8d918737282edc/experiments/687ba1c6b7b44cb0b3b4761bcd8ebb92/output/log
# ClearML Terminating local execution process - continuing execution remotely

# %%
# !python step2_preprocessing.py
# Out:
# ClearML Task: created new task id=9b67476e92a54722bb82f824927a72c0
# 2025-05-04 11:25:53,092 - clearml.Task - INFO - No repository found, storing script code instead
# 2025-05-04 11:25:54.095641: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746357954.115589   16724 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746357954.121834   16724 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 11:25:54.143495: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/727a6a00559349e08d8d918737282edc/experiments/9b67476e92a54722bb82f824927a72c0/output/log
# ClearML Terminating local execution process - continuing execution remotely

# %%
# !python step3_train_model.py
# Out:
# 2025-05-04 11:36:02.919032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746358562.938601   19388 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746358562.944601   19388 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 11:36:02.964527: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML Task: created new task id=68368d7ebc644fd2ade5d288b82f019d
# 2025-05-04 11:36:07,992 - clearml.Task - INFO - No repository found, storing script code instead
# ClearML results page: https://app.clear.ml/projects/727a6a00559349e08d8d918737282edc/experiments/68368d7ebc644fd2ade5d288b82f019d/output/log
# 2025-05-04 11:36:09,850 - clearml.Task - INFO - Waiting for repository detection and full package requirement analysis
# 2025-05-04 11:36:10,540 - clearml.Task - INFO - Finished repository detection and package analysis
# ClearML Terminating local execution process - continuing execution remotely

# %%
##stop

# %%
# !python main.py
# Out:
# ClearML Task: created new task id=86b1b2213bff459f8454c0798dfc1cac
# 2025-05-04 11:36:29,444 - clearml.Task - INFO - No repository found, storing script code instead
# 2025-05-04 11:36:30.435176: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746358590.454665   19527 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746358590.460674   19527 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-04 11:36:30.479976: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ClearML results page: https://app.clear.ml/projects/f56e8bf539d44fd7927f40e3bbd46f70/experiments/86b1b2213bff459f8454c0798dfc1cac/output/log
# ClearML pipeline page: https://app.clear.ml/pipelines/f56e8bf539d44fd7927f40e3bbd46f70/experiments/86b1b2213bff459f8454c0798dfc1cac
# Launching the next 1 steps
# Launching step [step1_upload_dataset]
# Launching step: step1_upload_dataset
# Parameters:
# None
# Configurations:
# {}
# Overrides:
# {}
# Launching the next 1 steps
# Launching step [step2_preprocessing]
# Launching step: step2_preprocessing
# Parameters:
# {'General/dataset_task_id': '${step1_upload_dataset.id}'}
# Configurations:
# {}
# Overrides:
# {}
# Launching the next 1 steps
# Launching step [step3_train_model]
# Launching step: step3_train_model
# Parameters:
# {'General/dataset_task_id': '${step2_preprocessing.id}'}
# Configurations:
# {}
# Overrides:
# {}
# Launching the next 0 steps
# Setting pipeline controller Task as failed (due to failed steps) !
#  done.
