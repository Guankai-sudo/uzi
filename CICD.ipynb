# %%
# !git clone https://github.com/Guankai-sudo/uzi/tree/main.git

# %%
# !pwd

# %%
# !pip install clearml

# %%
# !clearml-init

# %%
# !pip install ultralytics -q

# %%
# !python step1_upload_dataset.py

# %%
# !python step2_preprocessing.py

# %%
# !python step3_train_model.py

# %%
# !python task_hpo.py

# %%
# !python final_model.py

# %%
# !python main.py
